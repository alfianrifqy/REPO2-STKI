# %% [markdown]
# <a href="https://colab.research.google.com/github/alfianrifqy/REPO2-STKI/blob/main/TF_IDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('clean_dataset_stem.csv',sep=';')

# %%
dataset.shape
# Out:
# (902, 10)

# %%
dataset.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
#
#                                                Tweet  Sentimen  \
# 0  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 1  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 2  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
#
#                                               step01  \
# 0  cegah mata rantai covid   mari kita dirumah sa...
# 1  aku mohon yaallah semoga wabah covid   menghil...
# 2  pemprov papua naikkan status jadi tanggap daru...
#
#                                               tokens  \
# 0  ['cegah', 'mata', 'rantai', 'covid', 'mari', '...
# 1  ['aku', 'mohon', 'yaallah', 'semoga', 'wabah',...
# 2  ['pemprov', 'papua', 'naikkan', 'status', 'jad...
#
#                                         final_tokens  \
# 0  ['cegah', 'mata', 'rantai', 'covid', 'mari', '...
# 1  ['aku', 'mohon', 'yaallah', 'semoga', 'wabah',...
# 2  ['pemprov', 'papua', 'naikkan', 'status', 'jad...
#
#                                               step02  \
# 0  cegah mata rantai covid mari kita dirumah saja...
# 1  aku mohon yaallah semoga wabah covid menghilan...
# 2  pemprov papua naikkan status jadi tanggap daru...
#
#                                        finalText_str  \
# 0  cegah mata rantai covid mari kita dirumah saja...
# 1  aku mohon yaallah semoga wabah covid menghilan...
# 2  pemprov papua naikkan status jadi tanggap daru...
#
#                                        ProcessedText
# 0  cegah mata rantai covid kita rumah hingga hari...
# 1  aku mohon yaallah moga wabah covid hilang rama...
# 2  pemprov papua naik status jadi tanggap darurat...

# %%
dataset_feature = dataset['ProcessedText'].astype(str)

# %%
dataset_feature
# Out:
# 0      cegah mata rantai covid kita rumah hingga hari...
# 1      aku mohon yaallah moga wabah covid hilang rama...
# 2      pemprov papua naik status jadi tanggap darurat...
# 3                      covid nyampe prigen mbak hmm hoax
# 4      nyuruh orang pintar lu aja togog kerumun orang...
#                              ...
# 897    seluruh negara dunia alami masa sulit covid ra...
# 898    covid skripsi disaster selesai mau bgt bljr ma...
# 899    malam projek benda bincang malam fb satu belia...
# 900                          pontang panting koyak covid
# 901    masalah sekarang isu jangkit covid alaaaa bosa...
# Name: ProcessedText, Length: 902, dtype: object

# %%
dataset_label = dataset['Sentimen']

# %%
dataset_label
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      0.0
# 4     -1.0
#       ...
# 897    1.0
# 898    1.0
# 899    0.0
# 900   -1.0
# 901   -1.0
# Name: Sentimen, Length: 902, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Visualizing the target variable
plt.figure(figsize=(12,8))
sns.distplot(dataset_label, label=f'target, skew: {dataset_label.skew():.2f}')
plt.legend(loc='best')
plt.show()
# Out:
# /tmp/ipython-input-1470841120.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset_label, label=f'target, skew: {dataset_label.skew():.2f}')

# %%
dataset_label.value_counts()
# Out:
# Sentimen
#  1.0    441
#  0.0    266
# -1.0    195
# Name: count, dtype: int64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()

# %%
positive_reviews = dataset[(dataset["Sentimen"] == 1)]
negative_reviews = dataset[(dataset["Sentimen"] == -1)]
neutral_reviews = dataset[(dataset["Sentimen"] == 0)]

# %%
positive_reviews.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 6             6           6
# 7             7           7
#
#                                                Tweet  Sentimen  \
# 0  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 1  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 2  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
# 6  Selamat pagi, hari jum'at. Jum'at keempat di k...       1.0
# 7  Hikmah di balik musibah covid-19, smg para pej...       1.0
#
#                                               step01  \
# 0  cegah mata rantai covid   mari kita dirumah sa...
# 1  aku mohon yaallah semoga wabah covid   menghil...
# 2  pemprov papua naikkan status jadi tanggap daru...
# 6  selamat pagi hari jumat jumat keempat di kala ...
# 7  hikmah di balik musibah covid   smg para pejab...
#
#                                               tokens  \
# 0  ['cegah', 'mata', 'rantai', 'covid', 'mari', '...
# 1  ['aku', 'mohon', 'yaallah', 'semoga', 'wabah',...
# 2  ['pemprov', 'papua', 'naikkan', 'status', 'jad...
# 6  ['selamat', 'pagi', 'hari', 'jumat', 'jumat', ...
# 7  ['hikmah', 'di', 'balik', 'musibah', 'covid', ...
#
#                                         final_tokens  \
# 0  ['cegah', 'mata', 'rantai', 'covid', 'mari', '...
# 1  ['aku', 'mohon', 'yaallah', 'semoga', 'wabah',...
# 2  ['pemprov', 'papua', 'naikkan', 'status', 'jad...
# 6  ['selamat', 'pagi', 'hari', 'jumat', 'jumat', ...
# 7  ['hikmah', 'di', 'balik', 'musibah', 'covid', ...
#
#                                               step02  \
# 0  cegah mata rantai covid mari kita dirumah saja...
# 1  aku mohon yaallah semoga wabah covid menghilan...
# 2  pemprov papua naikkan status jadi tanggap daru...
# 6  selamat pagi hari jumat jumat keempat di kala ...
# 7  hikmah di balik musibah covid smg para pejabat...
#
#                                        finalText_str  \
# 0  cegah mata rantai covid mari kita dirumah saja...
# 1  aku mohon yaallah semoga wabah covid menghilan...
# 2  pemprov papua naikkan status jadi tanggap daru...
# 6  selamat pagi hari jumat jumat keempat di kala ...
# 7  hikmah di balik musibah covid smg para pejabat...
#
#                                        ProcessedText
# 0  cegah mata rantai covid kita rumah hingga hari...
# 1  aku mohon yaallah moga wabah covid hilang rama...
# 2  pemprov papua naik status jadi tanggap darurat...
# 6  selamat pagi hari jumat jumat empat kala pande...
# 7  hikmah balik musibah covid smg jabat perintah ...

# %%
Positive_tf_idf_vect = TfidfVectorizer(ngram_range=(1,2))
Positive_tf_idf = Positive_tf_idf_vect.fit_transform(positive_reviews["ProcessedText"].values)

# %%
Positive_tf_idf.shape
# Out:
# (441, 7781)

# %%
features = Positive_tf_idf_vect.get_feature_names_out()

# %%
idfValues = Positive_tf_idf_vect.idf_

# %%
d = dict(zip(features, 9 - idfValues))

# %%
sortedDict = sorted(d.items(), key = lambda d: d[1], reverse = True)

# %%
for i in range(200):
    print(sortedDict[i])
# Out:
# ('covid', np.float64(7.97247532660991))
# ('virus', np.float64(6.083077387817939))
# ('cegah', np.float64(6.067573201281974))
# ('sebar', np.float64(6.0195639820956135))
# ('corona', np.float64(5.934041808657451))
# ('moga', np.float64(5.878982031474424))
# ('sama', np.float64(5.878982031474424))
# ('rumah', np.float64(5.737331514411396))
# ('yg', np.float64(5.737331514411396))
# ('batas', np.float64(4.105914695258521))
# ('biasa', np.float64(4.105914695258521))
# ('bumi', np.float64(4.105914695258521))
# ('date', np.float64(4.105914695258521))
# ('himbau', np.float64(4.105914695258521))
# ('himbauan', np.float64(4.105914695258521))
# ('info', np.float64(4.105914695258521))
# ('jaga sehat', np.float64(4.105914695258521))
# ('juang', np.float64(4.105914695258521))
# ('kata', np.float64(4.105914695258521))
# ('kumpul', np.float64(4.105914695258521))
# ('kurang', np.float64(4.105914695258521))
# ('langkah', np.float64(4.105914695258521))
# ('langsung', np.float64(4.105914695258521))
# ('luar', np.float64(4.105914695258521))
# ('mata rantai', np.float64(4.105914695258521))
# ('mau', np.float64(4.105914695258521))
# ('nya', np.float64(4.105914695258521))
# ('org', np.float64(4.105914695258521))
# ('polres', np.float64(4.105914695258521))
# ('pulang', np.float64(4.105914695258521))
# ('rasa', np.float64(4.105914695258521))
# ('salah', np.float64(4.105914695258521))
# ('segala', np.float64(4.105914695258521))
# ('semprot', np.float64(4.105914695258521))
# ('tempat', np.float64(4.105914695258521))
# ('tenaga', np.float64(4.105914695258521))
# ('tidak', np.float64(4.105914695258521))
# ('yuk', np.float64(4.105914695258521))
# ('akan', np.float64(3.9881316596021374))
# ('aktivitas', np.float64(3.9881316596021374))
# ('ayo', np.float64(3.9881316596021374))
# ('bentuk', np.float64(3.9881316596021374))
# ('bisa', np.float64(3.9881316596021374))
# ('cegah virus', np.float64(3.9881316596021374))
# ('covid cepat', np.float64(3.9881316596021374))
# ('dan', np.float64(3.9881316596021374))
# ('dapat', np.float64(3.9881316596021374))
# ('desa', np.float64(3.9881316596021374))
# ('dlm', np.float64(3.9881316596021374))

# %%
# !pip3 install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.12/dist-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from wordcloud) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from wordcloud) (11.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plot

# %%
def PlotWordCloud(frequency):
    worcloudPlot = WordCloud(background_color="white", width=1500, height=1000)
    worcloudPlot.generate_from_frequencies(frequencies=frequency)
    plot.figure(figsize=(15,10))
    plot.imshow(worcloudPlot, interpolation="bilinear")
    plot.axis("off")
    plot.show()

# %%
PlotWordCloud(d)

# %%
negative_reviews.head()
# Out:
#     Unnamed: 0.1  Unnamed: 0  \
# 4              4           4
# 19            19          19
# 21            21          21
# 27            27          27
# 31            31          31
#
#                                                 Tweet  Sentimen  \
# 4   Nyuruh orang pintar, lu aja Togog. Itu kerumun...      -1.0
# 19  Berita seperti ini tidak akan ditengok oleh Mu...      -1.0
# 21  Temanggung, Jawa Tengah...anggota gugus tugas ...      -1.0
# 27  COVID-19 Telah Bermutasi? Ada Gelombang Kedua ...      -1.0
# 31  Berarti dah lama gak gitaran, mungkin mau biki...      -1.0
#
#                                                step01  \
# 4   nyuruh orang pintar lu aja togog itu kerumunan...
# 19  berita seperti ini tidak akan ditengok oleh mu...
# 21  temanggung jawa tengah anggota gugus tugas cov...
# 27  covid   telah bermutasi ada gelombang kedua vi...
# 31  berarti dah lama gak gitaran mungkin mau bikin...
#
#                                                tokens  \
# 4   ['nyuruh', 'orang', 'pintar', 'lu', 'aja', 'to...
# 19  ['berita', 'seperti', 'ini', 'tidak', 'akan', ...
# 21  ['temanggung', 'jawa', 'tengah', 'anggota', 'g...
# 27  ['covid', 'telah', 'bermutasi', 'ada', 'gelomb...
# 31  ['berarti', 'dah', 'lama', 'gak', 'gitaran', '...
#
#                                          final_tokens  \
# 4   ['nyuruh', 'orang', 'pintar', 'lu', 'aja', 'to...
# 19  ['berita', 'seperti', 'ini', 'tidak', 'akan', ...
# 21  ['temanggung', 'jawa', 'tengah', 'anggota', 'g...
# 27  ['covid', 'telah', 'bermutasi', 'ada', 'gelomb...
# 31  ['berarti', 'dah', 'lama', 'gak', 'gitaran', '...
#
#                                                step02  \
# 4   nyuruh orang pintar lu aja togog itu kerumunan...
# 19  berita seperti ini tidak akan ditengok oleh mu...
# 21  temanggung jawa tengah anggota gugus tugas cov...
# 27  covid telah bermutasi ada gelombang kedua viru...
# 31  berarti dah lama gak gitaran mungkin mau bikin...
#
#                                         finalText_str  \
# 4   nyuruh orang pintar lu aja togog itu kerumunan...
# 19  berita seperti ini tidak akan ditengok oleh mu...
# 21  temanggung jawa tengah anggota gugus tugas cov...
# 27  covid telah bermutasi ada gelombang kedua viru...
# 31  berarti dah lama gak gitaran mungkin mau bikin...
#
#                                         ProcessedText
# 4   nyuruh orang pintar lu aja togog kerumun orang...
# 19  berita ini akan tengok muflis dungu berita hoa...
# 21  tanggung jawa tengah anggota gugus tugas covid...
# 27            covid mutasi gelombang dua virus corona
# 31  arti dah lama gak gitar mungkin mau bikin albu...

# %%
Negative_tf_idf_vect = TfidfVectorizer(ngram_range=(1,2))
Negative_tf_idf = Negative_tf_idf_vect.fit_transform(negative_reviews["ProcessedText"].values)

# %%
Negative_tf_idf.shape
# Out:
# (195, 4174)

# %%
features = Negative_tf_idf_vect.get_feature_names_out()

# %%
idfValues = Negative_tf_idf_vect.idf_

# %%
d = dict(zip(features, 9 - idfValues))

# %%
sortedDict = sorted(d.items(), key = lambda d: d[1], reverse = True)

# %%
for i in range(200):
    print(sortedDict[i])
# Out:
# ('covid', np.float64(7.963632355829125))
# ('yg', np.float64(6.593086351677374))
# ('jadi', np.float64(5.940761165637683))
# ('orang', np.float64(5.8999391711174285))
# ('semua', np.float64(5.717617614323474))
# ('bukan', np.float64(5.666324319935923))
# ('kena', np.float64(5.612257098665648))
# ('jenazah', np.float64(5.555098684825699))
# ('mau', np.float64(5.555098684825699))
# ('sama', np.float64(5.494474063009264))
# ('tinggal', np.float64(5.494474063009264))
# ('virus', np.float64(5.494474063009264))
# ('mati', np.float64(5.360942670384741))
# ('rumah', np.float64(5.360942670384741))
# ('tolak', np.float64(5.360942670384741))
# ('aja', np.float64(5.2868346982310195))
# ('apa', np.float64(5.2868346982310195))
# ('buat', np.float64(5.2868346982310195))
# ('ga', np.float64(5.2868346982310195))
# ('kalo', np.float64(5.206791990557483))
# ('lebih', np.float64(5.206791990557483))
# ('pandemi', np.float64(5.206791990557483))
# ('tak', np.float64(5.206791990557483))
# ('corona', np.float64(5.119780613567853))
# ('lama', np.float64(5.119780613567853))
# ('masuk', np.float64(5.119780613567853))
# ('wabah', np.float64(5.119780613567853))
# ('berita', np.float64(5.024470433763528))
# ('biar', np.float64(5.024470433763528))
# ('gak', np.float64(5.024470433763528))
# ('berita covid', np.float64(4.108179701889373))
# ('besar', np.float64(4.108179701889373))
# ('biasa', np.float64(4.108179701889373))
# ('biaya', np.float64(4.108179701889373))
# ('biji', np.float64(4.108179701889373))
# ('bila', np.float64(4.108179701889373))
# ('bilang', np.float64(4.108179701889373))
# ('bisa', np.float64(4.108179701889373))
# ('bodoh', np.float64(4.108179701889373))
# ('bom', np.float64(4.108179701889373))
# ('bukan cuma', np.float64(4.108179701889373))
# ('cara', np.float64(4.108179701889373))
# ('cegah', np.float64(4.108179701889373))
# ('coba', np.float64(4.108179701889373))
# ('covid masuk', np.float64(4.108179701889373))
# ('covid tolak', np.float64(4.108179701889373))
# ('daerah', np.float64(4.108179701889373))
# ('dan', np.float64(4.108179701889373))

# %%
def PlotWordCloud(frequency):
    worcloudPlot = WordCloud(background_color="white", width=1500, height=1000)
    worcloudPlot.generate_from_frequencies(frequencies=frequency)
    plot.figure(figsize=(15,10))
    plot.imshow(worcloudPlot, interpolation="bilinear")
    plot.axis("off")
    plot.show()

# %%
PlotWordCloud(d)

# %%
neutral_reviews.head()
# Out:
#     Unnamed: 0.1  Unnamed: 0  \
# 3              3           3
# 5              5           5
# 22            22          22
# 23            23          23
# 30            30          30
#
#                                                 Tweet  Sentimen  \
# 3             Covid belum nyampe prigen mbak hmm hoax       0.0
# 5   Pikir2 balik byk mnde plk nk setelkn lepas covid.       0.0
# 22  Profil Operasional Bandara AP II di Tengah Pan...       0.0
# 23  Btw long weekend ni pada mau kemana... Dulu se...       0.0
# 30  Ada yang kek gue saking fokus sama berita soal...       0.0
#
#                                                step01  \
# 3             covid belum nyampe prigen mbak hmm hoax
# 5     pikir balik byk mnde plk nk setelkn lepas covid
# 22  profil operasional bandara ap ii di tengah pan...
# 23  btw long weekend ni pada mau kemana dulu sebel...
# 30  ada yang kek gue saking fokus sama berita soal...
#
#                                                tokens  \
# 3   ['covid', 'belum', 'nyampe', 'prigen', 'mbak',...
# 5   ['pikir', 'balik', 'byk', 'mnde', 'plk', 'nk',...
# 22  ['profil', 'operasional', 'bandara', 'ap', 'ii...
# 23  ['btw', 'long', 'weekend', 'ni', 'pada', 'mau'...
# 30  ['ada', 'yang', 'kek', 'gue', 'saking', 'fokus...
#
#                                          final_tokens  \
# 3   ['covid', 'belum', 'nyampe', 'prigen', 'mbak',...
# 5   ['pikir', 'balik', 'byk', 'mnde', 'plk', 'nk',...
# 22  ['profil', 'operasional', 'bandara', 'ap', 'ii...
# 23  ['btw', 'long', 'weekend', 'ni', 'pada', 'mau'...
# 30  ['ada', 'yang', 'kek', 'gue', 'saking', 'fokus...
#
#                                                step02  \
# 3             covid belum nyampe prigen mbak hmm hoax
# 5     pikir balik byk mnde plk nk setelkn lepas covid
# 22  profil operasional bandara ap ii di tengah pan...
# 23  btw long weekend ni pada mau kemana dulu sebel...
# 30  ada yang kek gue saking fokus sama berita soal...
#
#                                         finalText_str  \
# 3             covid belum nyampe prigen mbak hmm hoax
# 5     pikir balik byk mnde plk nk setelkn lepas covid
# 22  profil operasional bandara ap ii di tengah pan...
# 23  btw long weekend ni pada mau kemana dulu sebel...
# 30  ada yang kek gue saking fokus sama berita soal...
#
#                                         ProcessedText
# 3                   covid nyampe prigen mbak hmm hoax
# 5     pikir balik byk mnde plk nk setelkn lepas covid
# 22  profil operasional bandara ap ii tengah pandem...
# 23  btw long weekend ni mau dulu ada nya si covid ...
# 30  yang kek gue saking fokus sama berita soal cov...

# %%
Neutral_tf_idf_vect = TfidfVectorizer(ngram_range=(1,2))
Neutral_tf_idf = Neutral_tf_idf_vect.fit_transform(neutral_reviews["ProcessedText"].values)

# %%
Neutral_tf_idf.shape
# Out:
# (266, 5154)

# %%
features = Neutral_tf_idf_vect.get_feature_names_out()

# %%
idfValues = Neutral_tf_idf_vect.idf_

# %%
d = dict(zip(features, 9 - idfValues))

# %%
sortedDict = sorted(d.items(), key = lambda d: d[1], reverse = True)

# %%
for i in range(200):
    print(sortedDict[i])
# Out:
# ('covid', np.float64(7.96182742649497))
# ('yg', np.float64(6.101630795713687))
# ('orang', np.float64(5.5908051719476966))
# ('positif', np.float64(5.5482455575289))
# ('date', np.float64(5.408483615153742))
# ('hari', np.float64(5.408483615153742))
# ('indonesia', np.float64(5.3571903207661915))
# ('ni', np.float64(5.3571903207661915))
# ('ada', np.float64(5.303123099495915))
# ('mau', np.float64(5.303123099495915))
# ('pasien', np.float64(5.303123099495915))
# ('baru', np.float64(5.2459646856559665))
# ('jadi', np.float64(5.2459646856559665))
# ('virus', np.float64(5.2459646856559665))
# ('banyak', np.float64(5.185340063839531))
# ('lebih', np.float64(5.185340063839531))
# ('kasus', np.float64(5.12080154270196))
# ('positif covid', np.float64(5.12080154270196))
# ('tinggal', np.float64(5.12080154270196))
# ('kena', np.float64(5.051808671215009))
# ('pandemi', np.float64(5.051808671215009))
# ('update', np.float64(5.051808671215009))
# ('apa', np.float64(4.9777006990612875))
# ('rumah', np.float64(4.9777006990612875))
# ('buat', np.float64(4.897657991387751))
# ('bukan', np.float64(4.897657991387751))
# ('dgn', np.float64(4.897657991387751))
# ('di', np.float64(4.897657991387751))
# ('ga', np.float64(4.897657991387751))
# ('kalo', np.float64(4.897657991387751))
# ('pandemi covid', np.float64(4.897657991387751))
# ('sakit', np.float64(4.897657991387751))
# ('sebar', np.float64(4.897657991387751))
# ('tak', np.float64(4.897657991387751))
# ('tambah', np.float64(4.897657991387751))
# ('warga', np.float64(4.897657991387751))
# ('aku', np.float64(4.810646614398121))
# ('bagaimana', np.float64(4.810646614398121))
# ('ikut', np.float64(4.810646614398121))
# ('negara', np.float64(4.810646614398121))
# ('nya', np.float64(4.810646614398121))
# ('udah', np.float64(4.810646614398121))
# ('baik', np.float64(4.715336434593796))
# ('covid ni', np.float64(4.715336434593796))
# ('ini', np.float64(4.715336434593796))
# ('org', np.float64(4.715336434593796))
# ('perintah', np.float64(4.715336434593796))
# ('salah', np.float64(4.715336434593796))
# ('satu', np.float64(4.715336434593796))
# ('tanggal', np.float64(4.715336434593796))
# ('wabah', np.float64(4.715336434593796))
# ('corona', np.float64(4.6099759189359695))
# ('dunia', np.float64(4.6099759189359695))
# ('gak', np.float64(4.6099759189359695))
# ('jalan', np.float64(4.6099759189359695))
# ('jumlah', np.float64(4.6099759189359695))
# ('kata', np.float64(4.204510810827806))
# ('kes', np.float64(4.204510810827806))
# ('laku', np.float64(4.204510810827806))
# ('lalu', np.float64(4.204510810827806))
# ('lama', np.float64(4.204510810827806))
# ('lewat', np.float64(4.204510810827806))
# ('lihat', np.float64(4.204510810827806))
# ('link', np.float64(4.204510810827806))
# ('mulai', np.float64(4.204510810827806))
# ('musim', np.float64(4.204510810827806))
# ('nak', np.float64(4.204510810827806))
# ('nyata', np.float64(4.204510810827806))
# ('pdp', np.float64(4.204510810827806))
# ('pernah', np.float64(4.204510810827806))
# ('pertama', np.float64(4.204510810827806))
# ('rs', np.float64(4.204510810827806))
# ('sabtu', np.float64(4.204510810827806))
# ('sama', np.float64(4.204510810827806))
# ('serang', np.float64(4.204510810827806))
# ('siap', np.float64(4.204510810827806))
# ('tahu', np.float64(4.204510810827806))
# ('tetap', np.float64(4.204510810827806))
# ('tu', np.float64(4.204510810827806))
# ('tular', np.float64(4.204510810827806))
# ('video', np.float64(4.204510810827806))
# ('ya', np.float64(4.204510810827806))
# ('akhir', np.float64(4.022189254033851))
# ('balik', np.float64(4.022189254033851))
# ('batas', np.float64(4.022189254033851))
# ('beberapa', np.float64(4.022189254033851))
# ('beli', np.float64(4.022189254033851))
# ('belum', np.float64(4.022189254033851))
# ('benar', np.float64(4.022189254033851))
# ('berapa', np.float64(4.022189254033851))
# ('beri', np.float64(4.022189254033851))
# ('besar', np.float64(4.022189254033851))
# ('bilang', np.float64(4.022189254033851))
# ('cegah', np.float64(4.022189254033851))
# ('covid hari', np.float64(4.022189254033851))
# ('covid kabupaten', np.float64(4.022189254033851))
# ('covid kalo', np.float64(4.022189254033851))
# ('cuma', np.float64(4.022189254033851))
# ('dampak covid', np.float64(4.022189254033851))
# ('dari', np.float64(4.022189254033851))
# ('diri', np.float64(4.022189254033851))
# ('dlm', np.float64(4.022189254033851))
# ('dokter', np.float64(4.022189254033851))
# ('gaji', np.float64(4.022189254033851))
# ('gejala', np.float64(4.022189254033851))
# ('gin', np.float64(4.022189254033851))
# ('gugus tugas', np.float64(4.022189254033851))
# ('hati', np.float64(4.022189254033851))
# ('hilang', np.float64(4.022189254033851))
# ('hingga', np.float64(4.022189254033851))
# ('ibu', np.float64(4.022189254033851))
# ('jangan', np.float64(4.022189254033851))
# ('jd', np.float64(4.022189254033851))
# ('jg', np.float64(4.022189254033851))
# ('kasus positif', np.float64(4.022189254033851))
# ('kek', np.float64(4.022189254033851))
# ('kontak', np.float64(4.022189254033851))
# ('korban', np.float64(4.022189254033851))
# ('la', np.float64(4.022189254033851))
# ('langsung', np.float64(4.022189254033851))
# ('lebih baik', np.float64(4.022189254033851))
# ('lepas', np.float64(4.022189254033851))
# ('malah', np.float64(4.022189254033851))
# ('masker', np.float64(4.022189254033851))
# ('masyarakat', np.float64(4.022189254033851))

# %%
def PlotWordCloud(frequency):
    worcloudPlot = WordCloud(background_color="white", width=1500, height=1000)
    worcloudPlot.generate_from_frequencies(frequencies=frequency)
    plot.figure(figsize=(15,10))
    plot.imshow(worcloudPlot, interpolation="bilinear")
    plot.axis("off")
    plot.show()

# %%
PlotWordCloud(d)
